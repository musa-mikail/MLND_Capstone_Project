# %% [markdown]
# <a href="https://colab.research.google.com/github/datawiz1984/MLND_Capstone_Project/blob/master/image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image = cv2.imread('slide_1.PNG')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1002x728 at 0x7F4E2C079588>

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1002x728 at 0x7F4E2C079CF8>

# %%
edged=cv2.Canny(gray,30,200)
cv2_imshow(edged)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1002x728 at 0x7F4E2C079E10>
# -1

# %%
#use a copy of your image, e.g. - edged.copy(), since finding contours alter the image
#we have to add _, before the contours as an empty argument due to upgrade of the OpenCV version
_, contours, hierarchy=cv2.findContours(edged,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
cv2_imshow(edged)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1002x728 at 0x7F4E2C068080>
# -1

# %%
#use -1 as the 3rd parameter to draw all the contours
#cv2.drawContours(image,contours,-1,(25,0,0),1)
#cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
print('Total contours', str(len(contours)))
# Out:
# Total contours 226

# %%
temp_file = "current_file"
for c in contours:
  x,y,w,h = cv2.boundingRect(c)
  new_img=image[y:y+h,x:x+w]
  cv2.imwrite(temp_file + '.png', new_img)
  cv2_imshow(new_img)
  cv2.waitKey(1)
# Out:
# <PIL.Image.Image image mode=RGB size=31x6 at 0x7F4E2C079320>
# <PIL.Image.Image image mode=RGB size=31x7 at 0x7F4E2C079278>
# <PIL.Image.Image image mode=RGB size=25x8 at 0x7F4E2C079320>
# <PIL.Image.Image image mode=RGB size=53x20 at 0x7F4E2C079278>
# <PIL.Image.Image image mode=RGB size=50x21 at 0x7F4E2C0792E8>
# <PIL.Image.Image image mode=RGB size=53x21 at 0x7F4E2C0792B0>
# <PIL.Image.Image image mode=RGB size=2x2 at 0x7F4E2C0792E8>
# <PIL.Image.Image image mode=RGB size=51x40 at 0x7F4E2C0792B0>
# <PIL.Image.Image image mode=RGB size=44x40 at 0x7F4E2C0792E8>
# <PIL.Image.Image image mode=RGB size=1x2 at 0x7F4E2C0792B0>
# <PIL.Image.Image image mode=RGB size=45x49 at 0x7F4E2C0792E8>
# <PIL.Image.Image image mode=RGB size=20x18 at 0x7F4E2C0792B0>
# <PIL.Image.Image image mode=RGB size=4x3 at 0x7F4E2C0792E8>
# <PIL.Image.Image image mode=RGB size=49x51 at 0x7F4E2C0792B0>
# <PIL.Image.Image image mode=RGB size=52x54 at 0x7F4E2C0792E8>
# ...
